# %% [markdown]
# <a href="https://colab.research.google.com/github/Enda111/Enda-Data110-Fall2026-CRN21802/blob/main/Week2_Enda_Hughes_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 — In‑Class Python Work & Assignment
# **Student:** Enda Hughes
# **Course:** DATA 110
# *Prepared: September 15, 2026*
#
# This notebook combines everything covered **in class (Week 2)** and the **assignment** you will submit: run cells top‑to‑bottom, add your answers where prompted, and submit this file.
#
# ### Contents
# 1. [Part A — In‑Class Python Work](#part-a)
# 2. [Part B — Assignment: Anscombe’s Quartet](#part-b)

# %% [markdown]
# ---
#
# <a id='part-a'></a>
#
# ## Part A — In‑Class Python Work

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Use one clean and consistent style for all figures
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# This notebook uses the **2017 World Happiness Report** dataset, available in the course dataset repository: https://github.com/Reben80/Data110-21843--fall25/tree/main/dataset

# %%
# Load the dataset directly from GitHub
dataset_url = 'https://raw.githubusercontent.com/Reben80/Data110-21843--fall25/main/dataset/happiness_2017.csv'
df = pd.read_csv(dataset_url)

# %%
# 1. View the first few rows
print(df.head())
# Out:
#        Country  ... Confidence in national government
# 0       Norway  ...                          0.717160
# 1      Denmark  ...                          0.572353
# 2      Iceland  ...                          0.365042
# 3  Switzerland  ...                          0.819707
# 4      Finland  ...                          0.597539
#
# [5 rows x 14 columns]

# %%
# 2. Get summary statistics
print(df.describe())
# Out:
#            Rank  ...  Confidence in national government
# count  140.0000  ...                         127.000000
# mean    70.5000  ...                           0.493701
# std     40.5586  ...                           0.198235
# min      1.0000  ...                           0.110937
# 25%     35.7500  ...                           0.333884
# 50%     70.5000  ...                           0.473544
# 75%    105.2500  ...                           0.617711
# max    140.0000  ...                           0.964690
#
# [8 rows x 12 columns]

# %%
# 3. Check the shape (rows, columns)
print(df.shape)
# Out:
# (140, 14)

# %%
# 4. View column names
print(df.columns)
# Out:
# Index(['Country', 'Region', 'Rank', 'HappinessScore', 'Life Ladder',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government'],
#       dtype='object')

# %%
# 5. Get data types and info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            140 non-null    object
#  1   Region                             140 non-null    object
#  2   Rank                               140 non-null    int64
#  3   HappinessScore                     140 non-null    float64
#  4   Life Ladder                        140 non-null    float64
#  5   Log GDP per capita                 133 non-null    float64
#  6   Social support                     139 non-null    float64
#  7   Healthy life expectancy at birth   140 non-null    float64
#  8   Freedom to make life choices       139 non-null    float64
#  9   Generosity                         132 non-null    float64
#  10  Perceptions of corruption          128 non-null    float64
# ...

# %%
# 6. Count unique values in the 'Country' column (or any other relevant column)
print(df['Country'].value_counts())
# Out:
# Country
# Norway                      1
# Denmark                     1
# Iceland                     1
# Switzerland                 1
# Finland                     1
#                            ..
# Liberia                     1
# Guinea                      1
# Togo                        1
# Tanzania                    1
# Central African Republic    1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# ### Example 1: Happiness Score vs. Log GDP per Capita

# %%
# Scatter plot of Happiness Score vs Log GDP per Capita
plt.figure(figsize=(8, 5))
plt.scatter(df['Log GDP per capita'], df['HappinessScore'], color='#4C78A8', s=55, alpha=0.75)
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs. Log GDP per Capita', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Example 2: Happiness Score vs. Healthy Life Expectancy

# %%
# Scatter plot of Happiness Score vs Healthy Life Expectancy at Birth
plt.figure(figsize=(8, 5))
plt.scatter(df['Healthy life expectancy at birth'], df['HappinessScore'], color='#59A14F', s=55, alpha=0.75)
plt.xlabel('Healthy Life Expectancy at Birth')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs. Healthy Life Expectancy', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Tasks:
# - **Happiness Score vs Social Support** (`Social support`)
# - **Happiness Score vs Freedom to Make Life Choices** (`Freedom to make life choices`)
# - **Happiness Score vs Generosity** (`Generosity`)
#
# Update your code using the correct column names based on this.
#
# ### Extra Task:
# Create **two scatter plots** using columns that do not have a meaningful relationship. For example, you might plot **Generosity** against **Healthy Life Expectancy**.

# %%
# Happiness Score vs Social Support
plt.figure(figsize=(8, 5))
plt.scatter(df['Social support'], df['HappinessScore'], color='#4C78A8', s=55, alpha=0.75)
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs. Social Support', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Happiness Score vs Freedom to Make Life Choices
plt.figure(figsize=(8, 5))
plt.scatter(df['Freedom to make life choices'], df['HappinessScore'], color='#F28E2B', s=55, alpha=0.75)
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs. Freedom to Make Life Choices', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Happiness Score vs Generosity
plt.figure(figsize=(8, 5))
plt.scatter(df['Generosity'], df['HappinessScore'], color='#B279A2', s=55, alpha=0.75)
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs. Generosity', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Extra Task 1: Generosity vs Healthy Life Expectancy
plt.figure(figsize=(8, 5))
plt.scatter(df['Generosity'], df['Healthy life expectancy at birth'], color='#59A14F', s=55, alpha=0.75)
plt.xlabel('Generosity')
plt.ylabel('Healthy Life Expectancy at Birth')
plt.title('Generosity vs. Healthy Life Expectancy', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Extra Task 2: Generosity vs Social Support
plt.figure(figsize=(8, 5))
plt.scatter(df['Generosity'], df['Social support'], color='#E15759', s=55, alpha=0.75)
plt.xlabel('Generosity')
plt.ylabel('Social Support')
plt.title('Generosity vs. Social Support', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part A Observations
#
# - Happiness has a clear positive association with GDP per capita, healthy life expectancy, social support, and freedom to make life choices.
# - The relationship between happiness and generosity is weaker and more scattered.
# - The two extra plots do not show a strong, consistent pattern, illustrating that not every pair of variables has a meaningful relationship.

# %% [markdown]
# ---
#
# <a id='part-b'></a>
#
# ## Part B — Assignment: Anscombe’s Quartet

# %% [markdown]
# ### Step 1: Import Necessary Packages
#
# Before we begin, we need to import the necessary Python libraries for plotting and performing the regression. We'll use:
#
# - `matplotlib.pyplot` for creating the graph
# - `numpy` for numerical operations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step 2: Anscombe's Quartet Dataset
#
# This dataset is known as **Anscombe's Quartet**, created by statistician Francis Anscombe to illustrate the importance of visualizing data. Despite having nearly identical statistical properties (e.g., mean, variance, correlation, and linear regression), each dataset tells a very different story when graphed.
#
# - **x**: The independent variable, common across three datasets.
# - **y1, y2, y3**: Three different dependent variables associated with the same `x` values.
# - **x4, y4**: A special case where most of the `x` values are identical, with one outlier.
#
# #### Anscombe's Quartet:
#
# `

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.figure(figsize=(7, 5))
plt.scatter(x, y1, color='#4C78A8', s=65, alpha=0.85)
plt.xlabel('x')
plt.ylabel('y1')
plt.title('Anscombe Dataset I', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create a smooth regression line
x_line = np.linspace(min(x), max(x), 100)
regression_line = m * x_line + b

# Plot the data points and regression line
plt.figure(figsize=(7, 5))
plt.scatter(x, y1, color='#4C78A8', s=65, alpha=0.85, label='Dataset I')
plt.plot(x_line, regression_line, color='#E15759', linewidth=2.2, label=f'y = {m:.2f}x + {b:.2f}')
plt.xlabel('x')
plt.ylabel('y1')
plt.title('Anscombe Dataset I with Regression Line', fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Your Task:
#
# Perform the same linear regression process for the following datasets: y2, y3, and y4.
# Modify the code to calculate and plot the regression lines for each of these datasets.
# Use distinct colors for each plot and appropriately label the axes (y2, y3, etc.).
# Discuss any differences you observe when comparing the results across all datasets.
#
# #### Completed Regression Plots

# %%
# Linear regression for x and y2
m2, b2 = np.polyfit(x, y2, 1)
x_line = np.linspace(min(x), max(x), 100)
regression_line2 = m2 * x_line + b2
plt.figure(figsize=(7, 5))
plt.scatter(x, y2, color='#F28E2B', s=65, alpha=0.85, label='Dataset II')
plt.plot(x_line, regression_line2, color='#E15759', linewidth=2.2, label=f'y = {m2:.2f}x + {b2:.2f}')
plt.xlabel('x')
plt.ylabel('y2')
plt.title('Anscombe Dataset II with Regression Line', fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Linear regression for x and y3
m3, b3 = np.polyfit(x, y3, 1)
x_line = np.linspace(min(x), max(x), 100)
regression_line3 = m3 * x_line + b3
plt.figure(figsize=(7, 5))
plt.scatter(x, y3, color='#59A14F', s=65, alpha=0.85, label='Dataset III')
plt.plot(x_line, regression_line3, color='#E15759', linewidth=2.2, label=f'y = {m3:.2f}x + {b3:.2f}')
plt.xlabel('x')
plt.ylabel('y3')
plt.title('Anscombe Dataset III with Regression Line', fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Linear regression for x and y4, as requested in this cell
m4_comparison, b4_comparison = np.polyfit(x, y4, 1)
x_line = np.linspace(min(x), max(x), 100)
regression_line4_comparison = m4_comparison * x_line + b4_comparison
plt.figure(figsize=(7, 5))
plt.scatter(x, y4, color='#B279A2', s=65, alpha=0.85, label='x with y4')
plt.plot(x_line, regression_line4_comparison, color='#E15759', linewidth=2.2, label=f'y = {m4_comparison:.2f}x + {b4_comparison:.2f}')
plt.xlabel('x')
plt.ylabel('y4')
plt.title('Comparison Plot: x and y4', fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Linear regression for the fourth Anscombe dataset: x4 and y4
m4, b4 = np.polyfit(x4, y4, 1)
x4_line = np.linspace(min(x4), max(x4), 100)
regression_line4 = m4 * x4_line + b4
plt.figure(figsize=(7, 5))
plt.scatter(x4, y4, color='#76B7B2', s=65, alpha=0.85, label='Dataset IV')
plt.plot(x4_line, regression_line4, color='#E15759', linewidth=2.2, label=f'y = {m4:.2f}x + {b4:.2f}')
plt.xlabel('x4')
plt.ylabel('y4')
plt.title('Anscombe Dataset IV with Regression Line', fontweight='bold')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Reflection Question:
#
# After visualizing the linear regression for all four datasets in Anscombe's Quartet, reflect on the following:
#
# #### What is your reflection?
# - How do the datasets visually differ despite having similar summary statistics?
# - How did the outlier in the `x4, y4` dataset affect the regression line compared to the other datasets?
# - Why is it important to visualize data in addition to calculating summary statistics?
#
# Please provide your insights and discuss the importance of data visualization in understanding relationships between variables.
#
# #### Response
#
# 1. **Visual differences:** Although the datasets have nearly identical summary statistics and regression lines, their shapes are very different. Dataset I is approximately linear, Dataset II is curved, Dataset III contains an influential outlier, and Dataset IV forms a nearly vertical cluster with one distant point.
#
# 2. **Effect of the outlier:** In Dataset IV, the point at `x = 19` largely determines the positive regression line. Without it, the remaining points would provide little evidence of a relationship between the variables.
#
# 3. **Importance of visualization:** Summary statistics can make very different datasets appear identical. A graph reveals curvature, clustering, unusual observations, and influential outliers that averages and regression coefficients alone may conceal.

# %% [markdown]
# ---
#
# **Submission Reminder**
#
# - Before submitting, restart the kernel and run **Run All** to ensure a clean, reproducible output.
# - Save as `Week2_yourname_Assignment.ipynb`.
# - Upload to the designated location in MS Teams / GitHub as instructed.
