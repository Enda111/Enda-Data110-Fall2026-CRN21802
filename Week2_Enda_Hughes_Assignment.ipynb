# %% [markdown]
# <a href="https://colab.research.google.com/github/Reben80/Data110-21843--fall25/blob/main/Week2_Assignment_Fall_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 — In‑Class Python Work & Assignment
# *Prepared: September 9, 2026*
#
# This notebook combines everything covered **in class (Week 2)** and the **assignment** you will submit: run cells top‑to‑bottom, add your answers where prompted, and submit this file.
#
# ### Contents
# 1. [Part A — In‑Class Python Work](#part-a)
# 2. [Part B — Assignment: Anscombe’s Quartet](#part-b)

# %% [markdown]
# ---
#
# <a id='part-a'></a>
#
# ## Part A — In‑Class Python Work

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# The dataset we are using is the World Happiness Report dataset. which can be found in the file https://github.com/Reben80/Data110-21843--fall25/tree/main/dataset

# %%
# Load the dataset directly from GitHub
dataset_url = 'https://raw.githubusercontent.com/Reben80/Data110-21843--fall25/main/dataset/happiness_2017.csv'
df = pd.read_csv(dataset_url)

# %%
# 1. View the first few rows
print(df.head())
# Out:
#        Country          Region  Rank  HappinessScore  Life Ladder  \
# 0       Norway  Western Europe     1           7.537     7.578745
# 1      Denmark  Western Europe     2           7.522     7.593702
# 2      Iceland  Western Europe     3           7.504     7.476214
# 3  Switzerland  Western Europe     4           7.494     7.473593
# 4      Finland  Western Europe     5           7.469     7.788252
#
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0           11.081789        0.950128                         71.086586
# 1           10.748989        0.952100                         71.662498
# 2           10.760409        0.966753                         72.755981
# 3           10.955548        0.949661                         73.173759
# 4           10.612338        0.963826                         71.696960
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.953017    0.210104                   0.249711
# 1                      0.955416    0.145387                   0.181148
# 2                      0.938783    0.235479                   0.726845
# 3                      0.924997    0.167875                   0.316183
# 4                      0.962199   -0.012174                   0.192413
#
#    Positive affect  Negative affect  Confidence in national government
# 0         0.849100         0.202914                           0.717160
# 1         0.823667         0.205775                           0.572353
# 2         0.895255         0.148160                           0.365042
# 3         0.773997         0.195871                           0.819707
# 4         0.787137         0.176066                           0.597539

# %%
# 2. Get summary statistics
print(df.describe())
# Out:
#            Rank  HappinessScore  Life Ladder  Log GDP per capita  \
# count  140.0000      140.000000   140.000000          133.000000
# mean    70.5000        5.398907     5.491702            9.345615
# std     40.5586        1.109750     1.122178            1.184935
# min      1.0000        2.693000     2.661718            6.625341
# 25%     35.7500        4.542500     4.636694            8.545789
# 50%     70.5000        5.302000     5.586507            9.547693
# 75%    105.2500        6.212000     6.278276           10.313942
# max    140.0000        7.537000     7.788252           11.465231
#
#        Social support  Healthy life expectancy at birth  \
# count      139.000000                        140.000000
# mean         0.806711                         63.440981
# std          0.121117                          7.595597
# min          0.319589                         44.386528
# 25%          0.736748                         58.005130
# 50%          0.828953                         65.209110
# 75%          0.905827                         69.062944
# max          0.966753                         76.536362
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    139.000000  132.000000                 128.000000
# mean                       0.777874   -0.011614                   0.735870
# std                        0.127969    0.161064                   0.179799
# min                        0.427011   -0.296735                   0.161791
# 25%                        0.711635   -0.141405                   0.681880
# 50%                        0.811671   -0.035203                   0.782116
# 75%                        0.878373    0.098457                   0.857171
# max                        0.985178    0.628706                   0.954393
#
#        Positive affect  Negative affect  Confidence in national government
# count       139.000000       139.000000                         127.000000
# mean          0.699412         0.291164                           0.493701
# std           0.107246         0.091985                           0.198235
# min           0.420962         0.114123                           0.110937
# 25%           0.614203         0.219028                           0.333884
# 50%           0.710230         0.280323                           0.473544
# 75%           0.788236         0.345125                           0.617711
# max           0.895255         0.599335                           0.964690

# %%
# 3. Check the shape (rows, columns)
print(df.shape)
# Out:
# (140, 14)

# %%
# 4. View column names
print(df.columns)
# Out:
# Index(['Country', 'Region', 'Rank', 'HappinessScore', 'Life Ladder',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government'],
#       dtype='object')

# %%
# 5. Get data types and info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            140 non-null    object
#  1   Region                             140 non-null    object
#  2   Rank                               140 non-null    int64
#  3   HappinessScore                     140 non-null    float64
#  4   Life Ladder                        140 non-null    float64
#  5   Log GDP per capita                 133 non-null    float64
#  6   Social support                     139 non-null    float64
#  7   Healthy life expectancy at birth   140 non-null    float64
#  8   Freedom to make life choices       139 non-null    float64
#  9   Generosity                         132 non-null    float64
#  10  Perceptions of corruption          128 non-null    float64
#  11  Positive affect                    139 non-null    float64
#  12  Negative affect                    139 non-null    float64
#  13  Confidence in national government  127 non-null    float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 15.4+ KB
# None

# %%
# 6. Count unique values in the 'Country' column (or any other relevant column)
print(df['Country'].value_counts())
# Out:
# Country
# Norway                      1
# Denmark                     1
# Iceland                     1
# Switzerland                 1
# Finland                     1
#                            ..
# Liberia                     1
# Guinea                      1
# Togo                        1
# Tanzania                    1
# Central African Republic    1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# ### Example 1: Happiness Score vs. Log GDP per Capita

# %%
# Scatter plot of Happiness Score vs Log GDP per Capita
plt.scatter(df['Log GDP per capita'], df['HappinessScore'])
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Log GDP per Capita')
plt.show()

# %% [markdown]
# ### Example 2: Happiness Score vs. Healthy Life Expectancy

# %%
# Scatter plot of Happiness Score vs Healthy Life Expectancy at Birth
plt.scatter(df['Healthy life expectancy at birth'], df['HappinessScore'], color='green')
plt.xlabel('Healthy Life Expectancy at Birth')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Healthy Life Expectancy at Birth')
plt.show()

# %% [markdown]
# ###  Tasks:
# - **Happiness Score vs Social Support** (`Social support`)
# - **Happiness Score vs Freedom to Make Life Choices** (`Freedom to make life choices`)
# - **Happiness Score vs Generosity** (`Generosity`)
#
# Update your code using the correct column names based on this.
#
# ### Extra Task:
# Create **two scatter plots** using columns that do not have a meaningful relationship. For example, you might plot **Generosity** against **Healthy Life Expectancy**.

# %%
# Happiness Score vs Social Support
plt.scatter(df['Social support'], df['HappinessScore'], color='blue')
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Social Support')
plt.show()

# %%
# Happiness Score vs Freedom to Make Life Choices
plt.scatter(df['Freedom to make life choices'], df['HappinessScore'], color='orange')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Freedom to Make Life Choices')
plt.show()

# %%
# Happiness Score vs Generosity
plt.scatter(df['Generosity'], df['HappinessScore'], color='purple')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Generosity')
plt.show()

# %%
# Extra Task 1: Generosity vs Healthy Life Expectancy
plt.scatter(df['Generosity'], df['Healthy life expectancy at birth'], color='green')
plt.xlabel('Generosity')
plt.ylabel('Healthy Life Expectancy at Birth')
plt.title('Generosity vs Healthy Life Expectancy')
plt.show()

# %%
# Extra Task 2: Generosity vs Social Support
plt.scatter(df['Generosity'], df['Social support'], color='red')
plt.xlabel('Generosity')
plt.ylabel('Social Support')
plt.title('Generosity vs Social Support')
plt.show()

# %% [markdown]
# ---
#
# <a id='part-b'></a>
#
# ## Part B — Assignment: Anscombe’s Quartet

# %% [markdown]
# ### Step 1: Import Necessary Packages
#
# Before we begin, we need to import the necessary Python libraries for plotting and performing the regression. We'll use:
#
# - `matplotlib.pyplot` for creating the graph
# - `numpy` for numerical operations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step 2: Anscombe's Quartet Dataset
#
# This dataset is known as **Anscombe's Quartet**, created by statistician Francis Anscombe to illustrate the importance of visualizing data. Despite having nearly identical statistical properties (e.g., mean, variance, correlation, and linear regression), each dataset tells a very different story when graphed.
#
# - **x**: The independent variable, common across three datasets.
# - **y1, y2, y3**: Three different dependent variables associated with the same `x` values.
# - **x4, y4**: A special case where most of the `x` values are identical, with one outlier.
#
# #### Anscombe's Quartet:
#
# `

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y1)

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y1)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %% [markdown]
# ### Your Task:
#
# Perform the same linear regression process for the following datasets: y2, y3, and y4.
# Modify the code to calculate and plot the regression lines for each of these datasets.
# Use distinct colors for each plot and appropriately label the axes (y2, y3, etc.).
# Discuss any differences you observe when comparing the results across all datasets.

# %%
# Linear regression for x and y2
m2, b2 = np.polyfit(x, y2, 1)
x_line = np.linspace(min(x), max(x), 100)
regression_line2 = m2 * x_line + b2
plt.scatter(x, y2, color='blue')
plt.plot(x_line, regression_line2, color='orange')
plt.xlabel('x')
plt.ylabel('y2')
plt.title('Linear Regression for x and y2')
plt.show()

# %%
# Linear regression for x and y3
m3, b3 = np.polyfit(x, y3, 1)
x_line = np.linspace(min(x), max(x), 100)
regression_line3 = m3 * x_line + b3
plt.scatter(x, y3, color='green')
plt.plot(x_line, regression_line3, color='purple')
plt.xlabel('x')
plt.ylabel('y3')
plt.title('Linear Regression for x and y3')
plt.show()

# %%
# Linear regression for x and y4, as requested in this cell
m4_comparison, b4_comparison = np.polyfit(x, y4, 1)
x_line = np.linspace(min(x), max(x), 100)
regression_line4_comparison = m4_comparison * x_line + b4_comparison
plt.scatter(x, y4, color='orange')
plt.plot(x_line, regression_line4_comparison, color='brown')
plt.xlabel('x')
plt.ylabel('y4')
plt.title('Linear Regression for x and y4')
plt.show()

# %%
# Linear regression for the fourth Anscombe dataset: x4 and y4
m4, b4 = np.polyfit(x4, y4, 1)
x4_line = np.linspace(min(x4), max(x4), 100)
regression_line4 = m4 * x4_line + b4
plt.scatter(x4, y4, color='red')
plt.plot(x4_line, regression_line4, color='black')
plt.xlabel('x4')
plt.ylabel('y4')
plt.title('Linear Regression for x4 and y4')
plt.show()

# %% [markdown]
# ### Reflection Question:
#
# After visualizing the linear regression for all four datasets in Anscombe's Quartet, reflect on the following:
#
# #### What is your reflection?
# - How do the datasets visually differ despite having similar summary statistics?
# - How did the outlier in the `x4, y4` dataset affect the regression line compared to the other datasets?
# - Why is it important to visualize data in addition to calculating summary statistics?
#
# Please provide your insights and discuss the importance of data visualization in understanding relationships between variables.
#
# **Reflection:** Although the four datasets have very similar summary statistics and regression lines, their graphs look very different. The first dataset has a mostly linear pattern, the second has a curved pattern, and the third contains an outlier that strongly affects how the data appears. In the fourth dataset, nearly all the x-values are the same, while one distant point largely determines the regression line. This demonstrates that summary statistics alone can hide important patterns and unusual values. Visualizing the data makes it easier to identify relationships, curves, clusters, and outliers before drawing conclusions.

# %% [markdown]
# ---
#
# **Submission Reminder**
#
# - Before submitting, restart the kernel and run **Run All** to ensure a clean, reproducible output.
# - Save as `Week2_yourname_Assignment.ipynb`.
# - Upload to the designated location in MS Teams / GitHub as instructed.
